# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

data = pd.read_csv("kc_house_data.csv", parse_dates=['date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null datetime64[ns]
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: datetime64[ns](1), float64(5), int64(15)
# memory usage: 3.5 MB

# %%
data.tail()
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 21608              0      2009             0    98103  47.6993 -122.346
# 21609              0      2014             0    98146  47.5107 -122.362
# 21610              0      2009             0    98144  47.5944 -122.299
# 21611              0      2004             0    98027  47.5345 -122.069
# 21612              0      2008             0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 21608           1530        1509
# 21609           1830        7200
# 21610           1020        2007
# 21611           1410        1287
# 21612           1020        1357
#
# [5 rows x 21 columns]

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data['years_renovated'] = data['yr_renovated'] - data['yr_built']

# %%
numeric_data = ['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']
numeric_analysis = pd.DataFrame(data[numeric_data]).corr()
sns.heatmap(numeric_analysis)

# %%
y_data = data['price']
x_data = data.drop('price', axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.20, random_state=1)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((17290, 21), (4323, 21), (17290,), (4323,))

# %%
from sklearn.ensemble import RandomForestRegressor

rnd_clf = RandomForestRegressor(n_estimators=500, max_leaf_nodes=16, n_jobs=-1)
rnd_clf.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=16,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
preds = rnd_clf.predict(X_test)
r2_score(Y_test, preds)
# Out:
# 0.7178445811614341

# %%
# import libraries
import boto3, re, sys, math, json, os, sagemaker, urllib.request
from sagemaker import get_execution_role
import numpy as np                                
import pandas as pd                               
import matplotlib.pyplot as plt                   
from IPython.display import Image                 
from IPython.display import display               
from time import gmtime, strftime                 
from sagemaker.predictor import csv_serializer   

# Define IAM role
role = get_execution_role()
prefix = 'sagemaker/wimlds-xgboost-demo'
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'} # each region has its XGBoost container
my_region = boto3.session.Session().region_name # set the region of the instance
print("Success - the MySageMakerInstance is in the " + my_region + " region. You will use the " + containers[my_region] + " container for your SageMaker endpoint.")
# Out:
# Success - the MySageMakerInstance is in the us-east-2 region. You will use the 825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest container for your SageMaker endpoint.

# %%
bucket_name = 'wimlds-sagemaker-tutorial' # <--- CHANGE THIS VARIABLE TO A UNIQUE NAME FOR YOUR BUCKET
s3 = boto3.resource('s3')
try:
    if  my_region == 'us-east-1':
      s3.create_bucket(Bucket=bucket_name)
    else: 
      s3.create_bucket(Bucket=bucket_name, CreateBucketConfiguration={ 'LocationConstraint': my_region })
    print('S3 bucket created successfully')
except Exception as e:
    print('S3 error: ',e)
# Out:
# S3 error:  An error occurred (BucketAlreadyOwnedByYou) when calling the CreateBucket operation: Your previous request to create the named bucket succeeded and you already own it.

# %%
train_data, test_data = np.split(data.sample(frac=1, random_state=1729), [int(0.7 * len(data))])
print(train_data.shape, test_data.shape)
# Out:
# (15129, 22) (6484, 22)

# %%
train_data.head()
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 17399  5153900080 2014-07-14  199000.0         3       1.00         1510
# 16005  2754700095 2015-03-16  747000.0         3       1.50         1710
# 8382   4399200100 2015-04-28  288000.0         3       2.25         1560
# 7381   3897100275 2014-10-27  460000.0         3       1.75         1660
# 16824  9477201470 2014-10-22  379950.0         3       1.00         1270
#
#        sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 17399      9100     1.0           0     0  ...        1510              0
# 16005      5120     2.0           0     0  ...        1710              0
# 8382       9706     1.0           0     0  ...        1560              0
# 7381       9900     2.0           0     0  ...        1660              0
# 16824      6900     1.0           0     0  ...        1270              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 17399      1966             0    98003  47.3331 -122.319           1180
# 16005      1920             0    98115  47.6801 -122.305           1530
# 8382       1963             0    98002  47.3191 -122.213           1510
# 7381       1978             0    98033  47.6704 -122.184           1720
# 16824      1977             0    98034  47.7279 -122.192           1480
#
#        sqft_lot15  years_renovated
# 17399        7220            -1966
# 16005        5170            -1920
# 8382         9706            -1963
# 7381         6600            -1978
# 16824        7280            -1977
#
# [5 rows x 22 columns]

# %%
train_data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'years_renovated'],
#       dtype='object')

# %%
attributes = ['price','id', 'date', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15', 'years_renovated']
train_data = train_data[attributes]

# %%
train_data.to_csv('train.csv', index=False, header=False)

# %%
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')

# %%
sess = sagemaker.Session()

# %%
xgb = sagemaker.estimator.Estimator(containers[my_region],role, train_instance_count=1, train_instance_type='ml.m4.xlarge',output_path='s3://{}/{}/output'.format(bucket_name, prefix),sagemaker_session=sess)
xgb.set_hyperparameters(max_depth=5,eta=0.2,gamma=4,min_child_weight=6,subsample=0.8,silent=0,objective='reg:linear',num_round=100)

# %%
xgb.fit({'train': s3_input_train})
# Out:
# 2020-04-19 20:34:06 Starting - Starting the training job...
# 2020-04-19 20:34:07 Starting - Launching requested ML instances......
# 2020-04-19 20:35:33 Starting - Preparing the instances for training......
# 2020-04-19 20:36:35 Downloading - Downloading input data...
# 2020-04-19 20:36:55 Training - Downloading the training image..Arguments: train
# [2020-04-19:20:37:15:INFO] Running standalone xgboost training.
# [2020-04-19:20:37:15:INFO] Path /opt/ml/input/data/validation does not exist!
# [2020-04-19:20:37:15:INFO] File size need to be processed in the node: 1.69mb. Available memory size in the node: 8490.8mb
# [2020-04-19:20:37:15:INFO] Determined delimiter of CSV input is ','
# [20:37:15] S3DistributionType set as FullyReplicated
# [20:37:15] 15129x21 matrix with 317709 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [20:37:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [0]#011train-rmse:532723
# [20:37:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [1]#011train-rmse:439263
# [20:37:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [2]#011train-rmse:364807
# [20:37:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [3]#011train-rmse:306327
# [20:37:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [4]#011train-rmse:260974
# [20:37:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [5]#011train-rmse:225838
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [6]#011train-rmse:197879
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [7]#011train-rmse:178086
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [8]#011train-rmse:162084
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [9]#011train-rmse:150068
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [10]#011train-rmse:140110
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [11]#011train-rmse:131790
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [12]#011train-rmse:126346
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [13]#011train-rmse:121987
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [14]#011train-rmse:118937
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [15]#011train-rmse:116228
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [16]#011train-rmse:113917
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=5
# [17]#011train-rmse:111741
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [18]#011train-rmse:109849
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [19]#011train-rmse:108814
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [20]#011train-rmse:107353
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [21]#011train-rmse:106479
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [22]#011train-rmse:105241
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [23]#011train-rmse:104608
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [24]#011train-rmse:104024
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [25]#011train-rmse:103417
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [26]#011train-rmse:102887
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=5
# [27]#011train-rmse:102181
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [28]#011train-rmse:101474
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [29]#011train-rmse:101057
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [30]#011train-rmse:100717
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [31]#011train-rmse:100519
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [32]#011train-rmse:100025
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [33]#011train-rmse:99368.1
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [34]#011train-rmse:99059.3
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [35]#011train-rmse:98872.6
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [36]#011train-rmse:98053.2
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [37]#011train-rmse:97633.7
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [38]#011train-rmse:97465.1
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [39]#011train-rmse:96832.7
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [40]#011train-rmse:96198.3
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [41]#011train-rmse:95769.6
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [42]#011train-rmse:95260.4
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [43]#011train-rmse:94915.4
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=5
# [44]#011train-rmse:94429.2
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [45]#011train-rmse:94041.3
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [46]#011train-rmse:93507.6
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [47]#011train-rmse:93099.3
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [48]#011train-rmse:92707.1
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [49]#011train-rmse:92394.8
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [50]#011train-rmse:91966.1
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [51]#011train-rmse:91568.6
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [52]#011train-rmse:91428.4
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [53]#011train-rmse:91059.1
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [54]#011train-rmse:90343.4
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [55]#011train-rmse:89924.2
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [56]#011train-rmse:89512.6
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [57]#011train-rmse:89233.6
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [58]#011train-rmse:88685.3
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [59]#011train-rmse:88509.4
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [60]#011train-rmse:88251.9
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=5
# [61]#011train-rmse:87969.5
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [62]#011train-rmse:87729.3
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [63]#011train-rmse:87583.2
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [64]#011train-rmse:87417.5
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [65]#011train-rmse:86990.4
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [66]#011train-rmse:86828.1
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [67]#011train-rmse:86411.8
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [68]#011train-rmse:86032.7
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [69]#011train-rmse:85862.2
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [70]#011train-rmse:85549.2
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=5
# [71]#011train-rmse:85086.7
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [72]#011train-rmse:84754.7
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [73]#011train-rmse:84431.8
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [74]#011train-rmse:84159.9
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [75]#011train-rmse:83633.4
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [76]#011train-rmse:83178.3
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [77]#011train-rmse:83111.3
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [78]#011train-rmse:82775.4
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [79]#011train-rmse:82449.7
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [80]#011train-rmse:82389.5
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=5
# [81]#011train-rmse:81985.4
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [82]#011train-rmse:81889.8
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [83]#011train-rmse:81594.7
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [84]#011train-rmse:81309.2
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [85]#011train-rmse:81079.8
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [86]#011train-rmse:80973
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=5
# [87]#011train-rmse:80778.6
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [88]#011train-rmse:80592.6
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [89]#011train-rmse:80429.8
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=5
# [90]#011train-rmse:80265.9
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [91]#011train-rmse:80210.5
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=5
# [92]#011train-rmse:80012.6
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [93]#011train-rmse:79871.2
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [94]#011train-rmse:79423.3
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [95]#011train-rmse:79283
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [96]#011train-rmse:78979.6
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [97]#011train-rmse:78841.2
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [98]#011train-rmse:78633.8
# [20:37:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=5
# [99]#011train-rmse:78445
# 2020-04-19 20:37:27 Uploading - Uploading generated training model
# 2020-04-19 20:37:27 Completed - Training job completed
# Training seconds: 52
# Billable seconds: 52

# %%
xgb_predictor = xgb.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge')
# Out:
# -----------!

# %%
test_data.head()
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 9581   5466310730 2014-08-22  165000.0         3       2.50         1660
# 11264  7950303290 2015-04-02  499950.0         3       1.75         2060
# 15165  3034200660 2014-06-19  507000.0         3       2.50         2120
# 10336  7525300240 2015-02-19  750000.0         4       2.25         2820
# 9861   7805450560 2014-08-20  960000.0         4       2.50         3110
#
#        sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 9581       2415     2.0           0     0  ...        1660              0
# 11264      3500     1.0           0     0  ...        1030           1030
# 15165      7201     2.0           0     0  ...        2120              0
# 10336      9602     1.0           0     1  ...        1950            870
# 9861      11397     2.0           0     3  ...        3110              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 9581       1983             0    98042  47.3763 -122.148           1740
# 11264      1951             0    98118  47.5635 -122.282           1110
# 15165      2003             0    98133  47.7174 -122.337           1930
# 10336      1974             0    98008  47.5881 -122.113           2890
# 9861       1984             0    98006  47.5623 -122.106           3110
#
#        sqft_lot15  years_renovated
# 9581         2624            -1983
# 11264        6000            -1951
# 15165        7206            -2003
# 10336        9602            -1974
# 9861        11586            -1984
#
# [5 rows x 22 columns]

# %%
test_data_array = test_data.drop(['price','date'], axis=1).values #load the data into an array

# %%
test_data_array
# Out:
# array([[ 5.46631073e+09,  3.00000000e+00,  2.50000000e+00, ...,
#          1.74000000e+03,  2.62400000e+03, -1.98300000e+03],
#        [ 7.95030329e+09,  3.00000000e+00,  1.75000000e+00, ...,
#          1.11000000e+03,  6.00000000e+03, -1.95100000e+03],
#        [ 3.03420066e+09,  3.00000000e+00,  2.50000000e+00, ...,
#          1.93000000e+03,  7.20600000e+03, -2.00300000e+03],
#        ...,
#        [ 4.31070160e+09,  3.00000000e+00,  2.50000000e+00, ...,
#          1.41000000e+03,  1.35500000e+03, -2.00300000e+03],
#        [ 5.56130128e+09,  3.00000000e+00,  2.25000000e+00, ...,
#          2.73000000e+03,  3.64040000e+04, -1.97800000e+03],
#        [ 2.32006925e+09,  3.00000000e+00,  1.00000000e+00, ...,
#          1.21000000e+03,  8.98500000e+03, -1.95900000e+03]])

# %%
xgb_predictor.content_type = 'text/csv' # set the data type for an inference
xgb_predictor.serializer = csv_serializer # set the serializer type

# %%
predictions = xgb_predictor.predict(test_data_array).decode('utf-8') # predict!
predictions_array = np.fromstring(predictions[1:], sep=',') # and turn the prediction into an array
print(predictions_array.shape)
# Out:
# (6484,)

# %%
sagemaker.Session().delete_endpoint(xgb_predictor.endpoint)
bucket_to_delete = boto3.resource('s3').Bucket(bucket_name)
bucket_to_delete.objects.all().delete()
# Out:
# [{'ResponseMetadata': {'RequestId': '42480FCA5E96C721',
#    'HostId': 'pwY++8P+bksFfs84/GzlDKwZj/SAyQWMzsguHYb/nphmARF7MOUXaXdL1iBM356Ij9GkTdMxRWM=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'pwY++8P+bksFfs84/GzlDKwZj/SAyQWMzsguHYb/nphmARF7MOUXaXdL1iBM356Ij9GkTdMxRWM=',
#     'x-amz-request-id': '42480FCA5E96C721',
#     'date': 'Sun, 19 Apr 2020 21:19:16 GMT',
#     'connection': 'close',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'sagemaker/wimlds-xgboost-demo/output/xgboost-2020-04-19-20-34-06-206/output/model.tar.gz'},
#    {'Key': 'sagemaker/wimlds-xgboost-demo/train/train.csv'},
#    {'Key': 'sagemaker/wimlds-xgboost-demo/output/xgboost-2020-04-19-20-16-50-103/output/model.tar.gz'}]}]
