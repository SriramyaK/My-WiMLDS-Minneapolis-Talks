# %% [markdown]
# # Regression with Random Forest & Amazon SageMaker XGBoost algorithm
#
# ---
#
# ### Introduction
#
# The best way to learn how to use Amazon SageMaker is to create, train, and deploy a simple machine learning model.
#
# To do this, you need the following:
#
# 1. **A dataset**. We will use [KaggleDatasets : Housing prices in King County,Seattle US](https://www.kaggle.com/harlfoxem/housesalesprediction). This dataset contains house sale prices for King County in Seattle, sold between May 2014 and May 2015.It's a great dataset for evaluating simple regression models.
#
# 2. **An algorithm**. We will use the Random Forest algorithm in scikit-learn and XGBoost Algorithm provided by Amazon SageMaker to train the model using the housing dataset and predict the prices.
#
# You also need a few resources for storing your data and running the code in this notebook:
#
# 1. An **Amazon Simple Storage Service (Amazon S3) bucket** to store the training data and the model artifacts that Amazon SageMaker creates when it trains the model.
#
# 2. An **Amazon SageMaker notebook** instance to prepare and process data and to train and deploy a machine learning model.
#
# 3. A **Jupyter notebook** to use with the notebook instance to prepare your training data and train and deploy the model.
#
# **Important**
#
# To train, deploy, and validate a model in Amazon SageMaker, you can use one of these methods:
#
#     1. Amazon SageMaker Python SDK.
#     2. AWS SDK for Python (Boto 3).
#
# ### Amazon Sagemaker Python SDK vs AWS SDK for Python(Boto 3)
#
# The Amazon SageMaker Python SDK abstracts several implementation details, and is easy to use. If you're a first-time Amazon SageMaker user, aws recommends that you use it to train, deploy, and validate the model.
#
# On the other hand, Boto 3 is the Amazon Web Services (AWS) SDK for Python. It enables Python developers to create, configure, and manage AWS services, such as EC2 and S3. Boto provides an easy to use, object-oriented API, as well as low-level access to AWS services.
#
# Today we will learn how to create all of the resources that you need to train, and deploy a model using **Amazon Sagemaker Python SDK**.
#
# The steps include:
#
# 1. Fetching the dataset.
# 2. Explore and Transform the Training Data so that it can be fed to Amazon SageMaker algorithms.
#     1. Feature Engineering and Data Visualizations.
#     2. Prepare the data.
#     3. Data Ingestion.
# 3. Train a Model.
#     1. Launching a training job with the Python SDK.
# 4. Deploy the Model to Amazon SageMaker.
# 5. Validate the Model.
# 6. Integrating Amazon SageMaker Endpoints into Internet-facing Applications.
# 7. Clean up

# %% [markdown]
# ## Decision Tree
#
# - A decision tree is built top-down from a root node and involves partitioning the data into subsets that contain instances with similar values (homogenous).
#
# - Decision tree builds regression or classification models in the form of a tree structure.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image](https://github.com/SriramyaK/My-WiMLDS-Minneapolis-Talks/blob/master/WiMLDS/0_cant-HQdfMju-GxG.gif?raw=true)

# %% [markdown]
# In bidimensional terms (using only 2 variables), DTs partition the data universe into a set of rectangles, and fit a model in each one of those rectangles. They are simple yet powerful, and a great tool for data scientists.

# %% [markdown]
# ### Fable of blind men and elephant

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Fetching the dataset

# %%
import pandas as pd # library for data manipulation and analysis.
import numpy as np # library for scientific computing, provides high-performance, easy to use structures and data analysis tools. 
import matplotlib.pyplot as plt # Plotting library
import seaborn as sns # data visualization library
sns.set(style="darkgrid")

data = pd.read_csv("kc_house_data.csv", parse_dates=['date'])

# %% [markdown]
# ### Explore and Transform the Training Data so that it can be fed to Amazon SageMaker algorithms.
#
# Let's start exploring the data. First, let's understand how the features are distributed and check if they have any missing values.

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null datetime64[ns]
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: datetime64[ns](1), float64(5), int64(15)
# memory usage: 3.5 MB

# %%
data.tail()
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 21608              0      2009             0    98103  47.6993 -122.346
# 21609              0      2014             0    98146  47.5107 -122.362
# 21610              0      2009             0    98144  47.5944 -122.299
# 21611              0      2004             0    98027  47.5345 -122.069
# 21612              0      2008             0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 21608           1530        1509
# 21609           1830        7200
# 21610           1020        2007
# 21611           1410        1287
# 21612           1020        1357
#
# [5 rows x 21 columns]

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# #### Feature Engineering and Data Visualizations:
#
# Next, let's look at how our features relate to the target that we are attempting to predict.

# %%
#data['years_renovated'] = data['yr_renovated'] - data['yr_built']

# %%
numeric_data = ['id','price','bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']
numeric_analysis = pd.DataFrame(data[numeric_data]).corr()
sns.heatmap(numeric_analysis)

# %%
attributes = ['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']

y_data = data['price']
x_data = data [attributes]

# %% [markdown]
# #### Preparing the data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.20, random_state=1)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((17290, 18), (4323, 18), (17290,), (4323,))

# %%
x_train.head()
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 7291          3       1.75         2190      7021     1.0           0     2
# 14835         3       2.50         2370      6840     2.0           0     0
# 15880         2       1.00         1230      3800     1.0           0     0
# 8812          4       2.25         2510      9963     1.0           0     0
# 17220         3       1.00         1160      7491     1.0           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 7291           4      7        1390            800      1953             0
# 14835          3      9        2370              0      1987             0
# 15880          3      7        1230              0      1928             0
# 8812           4      9        2200            310      1967             0
# 17220          4      6        1160              0      1917             0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15
# 7291     98178  47.5033 -122.232           2180        7155
# 14835    98119  47.6503 -122.366           1590        4400
# 15880    98115  47.6797 -122.292           1610        3800
# 8812     98005  47.5973 -122.177           3110        9963
# 17220    98177  47.7024 -122.359           1800        2267

# %%
trainX = pd.DataFrame(x_train, columns=attributes)
trainX['target'] = y_train

testX = pd.DataFrame(x_test, columns=attributes)
testX['target'] = y_test

# %%
trainX.head()
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 7291          3       1.75         2190      7021     1.0           0     2
# 14835         3       2.50         2370      6840     2.0           0     0
# 15880         2       1.00         1230      3800     1.0           0     0
# 8812          4       2.25         2510      9963     1.0           0     0
# 17220         3       1.00         1160      7491     1.0           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 7291           4      7        1390            800      1953             0
# 14835          3      9        2370              0      1987             0
# 15880          3      7        1230              0      1928             0
# 8812           4      9        2200            310      1967             0
# 17220          4      6        1160              0      1917             0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15    target
# 7291     98178  47.5033 -122.232           2180        7155  353000.0
# 14835    98119  47.6503 -122.366           1590        4400  300523.0
# 15880    98115  47.6797 -122.292           1610        3800  435000.0
# 8812     98005  47.5973 -122.177           3110        9963  800000.0
# 17220    98177  47.7024 -122.359           1800        2267  417500.0

# %%
trainX.to_csv('housing_train.csv')
testX.to_csv('housing_test.csv')

# %% [markdown]
# #### Data Ingestion
#
# Now we'll copy the file to S3 for Amazon SageMaker's managed training to pickup.This should be within the same region as the Notebook Instance, training, and hosting.

# %%
import datetime
import tarfile

import boto3
from sagemaker import get_execution_role
import sagemaker

m_boto3 = boto3.client('sagemaker')

sess = sagemaker.Session()

region = sess.boto_session.region_name

bucket = sess.default_bucket()  # this could also be a hard-coded bucket name

print('Using bucket ' + bucket)
# Out:
# Using bucket sagemaker-us-east-1-262760754591

# %%
# send data to S3. SageMaker will take training data from s3
trainpath = sess.upload_data(
    path='housing_train.csv', bucket=bucket,
    key_prefix='sagemaker/sklearncontainer')

testpath = sess.upload_data(
    path='housing_test.csv', bucket=bucket,
    key_prefix='sagemaker/sklearncontainer')

# %% [markdown]
# #### Prepare a Scikit-learn Training Script
#
# Our Scikit-learn training script must be a Python 2.7 or 3.6 compatible source file.
#
# The training script is similar to a training script you might run outside of SageMaker, but you can access useful properties about the training environment through various environment variables. For example:
#
#     - SM_MODEL_DIR:  A string that represents the path where the training job writes the model artifacts to. After training, artifacts in this directory are uploaded to S3 for model hosting.
#
#     - SM_OUTPUT_DATA_DIR: A string representing the filesystem path to write output artifacts to. Output artifacts may include checkpoints, graphs, and other files to save, not including model artifacts. These artifacts are compressed and uploaded to S3 to the same S3 prefix as the model artifacts.
#
# Supposing two input channels, ‘train’ and ‘test’, were used in the call to the Scikit-learn estimator’s fit() method, the following will be set, following the format “SM_CHANNEL_[channel_name]”:
#
#     - SM_CHANNEL_TRAIN: A string representing the path to the directory containing data in the ‘train’ channel
#
#     - SM_CHANNEL_TEST: Same as above, but for the ‘test’ channel.
#
# [Refer Sagemaker Documentation](https://sagemaker.readthedocs.io/en/stable/using_sklearn.html#prepare-a-scikit-learn-training-script)
#
# A typical training script loads data from the input channels, configures training with hyperparameters, trains a model, and saves a model to model_dir so that it can be hosted later. Hyperparameters are passed to your script as arguments and can be retrieved with an argparse.ArgumentParser instance.
#
# The argparse module makes it easy to write user-friendly command-line interfaces. The program defines what arguments it requires, and argparse will figure out how to parse those out of sys.argv. The argparse module also automatically generates help and usage messages and issues errors when users give the program invalid arguments.
#
#
# For example, a training script might start with the following:

# %%
# %%writefile script.py

import argparse
import os

import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.externals import joblib
from sklearn.metrics import explained_variance_score, r2_score



# inference functions ---------------
def model_fn(model_dir):
    clf = joblib.load(os.path.join(model_dir, "model.joblib"))
    return clf

if __name__ =='__main__':

    print('extracting arguments')
    parser = argparse.ArgumentParser()

    # hyperparameters sent by the client are passed as command-line arguments to the script.
    # to simplify the demo we don't use all sklearn RandomForest hyperparameters
    parser.add_argument('--n-estimators', type=int, default=100)
    parser.add_argument('--max_leaf_nodes', type=int, default=10)
    

    # Data, model, and output directories
    parser.add_argument('--model-dir', type=str, default=os.environ.get('SM_MODEL_DIR'))
    parser.add_argument('--train', type=str, default=os.environ.get('SM_CHANNEL_TRAIN'))
    parser.add_argument('--test', type=str, default=os.environ.get('SM_CHANNEL_TEST'))
    parser.add_argument('--train-file', type=str, default='housing_train.csv')
    parser.add_argument('--test-file', type=str, default='housing_test.csv')
    
    args, _ = parser.parse_known_args()
    
    print('reading data')
    train_df = pd.read_csv(os.path.join(args.train, args.train_file))
    test_df = pd.read_csv(os.path.join(args.test, args.test_file))

    print('building training and testing datasets')
    attributes = ['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']
    X_train = train_df[attributes]
    X_test = test_df[attributes]
    y_train = train_df['target']
    y_test = test_df['target']
    
    # train
    print('training model')
    model = RandomForestRegressor(
        n_estimators=args.n_estimators,
        max_leaf_nodes =args.max_leaf_nodes,
        n_jobs=-1)
    
    model.fit(X_train, y_train)
     
    # persist model
    path = os.path.join(args.model_dir, "model.joblib")
    joblib.dump(model, path)
    print('model persisted at ' + path)
    
    # print explained_variance_score 
    print('validating model')
    predictions = model.predict(X_test)
    print("Explained Variance Score is " + str(explained_variance_score(y_test, predictions).round(2)))
    print("R2 score : %.2f" % r2_score(y_test,predictions))
# Out:
# Writing script.py

# %% [markdown]
# ## Local Training
#
# Script arguments allows us to remove from the script any SageMaker-specific configuration, and run locally

# %%
! python script.py --n-estimators 500 \
                   --max-leaf-nodes 16 \
                   --model-dir ./ \
                   --train ./ \
                   --test ./ \
# Out:
# extracting arguments
# reading data
# building training and testing datasets
# training model
# model persisted at ./model.joblib
# validating model
# Explained Variance Score is 0.68
# R2 score : 0.68

# %% [markdown]
# ## SageMaker Training - Launching a training job with the Python SDK
#
# ### Create an Estimator
#
# You run Scikit-learn training scripts on SageMaker by creating SKLearn Estimators. Call the fit method on a SKLearn Estimator to start a SageMaker training job. The following code sample shows how you train a custom Scikit-learn script named “script.py”, passing in two hyperparameters ('n-estimators', 'max_leaf_nodes'), and using two input channel directories (‘train’ and ‘test’).

# %%
# We use the Estimator from the SageMaker Python SDK
from sagemaker.sklearn.estimator import SKLearn

sklearn_estimator = SKLearn(
    entry_point='script.py',
    role = get_execution_role(),
    train_instance_count=1,
    train_instance_type='ml.m4.xlarge',
    framework_version='0.20.0',
    base_job_name='rf-scikit',
    hyperparameters = {'n-estimators': 500,
                       'max_leaf_nodes': 16 
                       })

# %%
# launch training job, with asynchronous call
sklearn_estimator.fit({'train':trainpath, 'test': testpath}, wait=False)

# %% [markdown]
# ## Deploy to a real-time endpoint
#
#
# ### Deploy with Python SDK
#
# An Estimator could be deployed directly after training, with an Estimator.deploy() but here we are using the more extensive process of creating a model from s3 artifacts, that could be used to deploy a model that was trained in a different session or even out of SageMaker.

# %%
sklearn_estimator.latest_training_job.wait(logs='None')
artifact = m_boto3.describe_training_job(
    TrainingJobName=sklearn_estimator.latest_training_job.name)['ModelArtifacts']['S3ModelArtifacts']

print('Model artifact persisted at ' + artifact)
# Out:
# 2020-04-24 21:48:58 Starting - Starting the training job
# 2020-04-24 21:49:00 Starting - Launching requested ML instances............
# 2020-04-24 21:50:06 Starting - Preparing the instances for training..........
# 2020-04-24 21:51:01 Downloading - Downloading input data....
# 2020-04-24 21:51:27 Training - Downloading the training image...
# 2020-04-24 21:51:48 Training - Training image download completed. Training in progress....
# 2020-04-24 21:52:04 Uploading - Uploading generated training model
# 2020-04-24 21:52:11 Completed - Training job completed
# Model artifact persisted at s3://sagemaker-us-east-1-262760754591/rf-scikit-2020-04-24-21-48-57-211/output/model.tar.gz

# %%
predictor = sklearn_estimator.deploy(instance_type='ml.m4.xlarge',initial_instance_count=1)
# Out:
# ---------------!

# %% [markdown]
# ### Invoke with the Python SDK

# %%
attributes = ['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']
print(predictor.predict(testX[attributes]))
# Out:
# [ 522866.64815341  468811.93460939  551243.6250504  ...  275341.74809002
#  2024476.51824543  459590.25565695]

# %%
predictions = predictor.predict(testX[attributes])

# %%
from sklearn.metrics import r2_score
print("R2 score : %.2f" % r2_score(testX['target'],predictions))
# Out:
# R2 score : 0.73

# %% [markdown]
# ### Don't forget to delete the endpoint !

# %%
sagemaker.Session().delete_endpoint(predictor.endpoint)
# bucket_to_delete = boto3.resource('s3').Bucket(bucket_name)
# bucket_to_delete.objects.all().delete()

# %% [markdown]
# ## XG Boost Algorithm

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# import libraries
import boto3, re, sys, math, json, os, sagemaker, urllib.request
from sagemaker import get_execution_role
import numpy as np                                
import pandas as pd                               
import matplotlib.pyplot as plt                   
from IPython.display import Image                 
from IPython.display import display               
from time import gmtime, strftime                 
from sagemaker.predictor import csv_serializer   

# Define IAM role and assign S3 bucket
role = get_execution_role()
prefix = 'sagemaker/wimlds-sagemaker-xgboost-demo'
bucket_name = 'sagemaker-us-east-1-262760754591' # <--- CHANGE THIS VARIABLE TO A UNIQUE NAME FOR YOUR BUCKET

containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'} # each region has its XGBoost container

my_region = boto3.session.Session().region_name # set the region of the instance
print("Success - the MySageMakerInstance is in the " + my_region + " region. You will use the " + containers[my_region] + " container for your SageMaker endpoint.")
# Out:
# Success - the MySageMakerInstance is in the us-east-1 region. You will use the 811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest container for your SageMaker endpoint.

# %% [markdown]
# ### Prepare the data

# %%
train_data, test_data = np.split(data.sample(frac=1, random_state=1729), [int(0.7 * len(data))])
print(train_data.shape, test_data.shape)
# Out:
# (15129, 21) (6484, 21)

# %%
train_data.head()
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 17399  5153900080 2014-07-14  199000.0         3       1.00         1510
# 16005  2754700095 2015-03-16  747000.0         3       1.50         1710
# 8382   4399200100 2015-04-28  288000.0         3       2.25         1560
# 7381   3897100275 2014-10-27  460000.0         3       1.75         1660
# 16824  9477201470 2014-10-22  379950.0         3       1.00         1270
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 17399      9100     1.0           0     0  ...      7        1510
# 16005      5120     2.0           0     0  ...      7        1710
# 8382       9706     1.0           0     0  ...      7        1560
# 7381       9900     2.0           0     0  ...      8        1660
# 16824      6900     1.0           0     0  ...      7        1270
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 17399              0      1966             0    98003  47.3331 -122.319
# 16005              0      1920             0    98115  47.6801 -122.305
# 8382               0      1963             0    98002  47.3191 -122.213
# 7381               0      1978             0    98033  47.6704 -122.184
# 16824              0      1977             0    98034  47.7279 -122.192
#
#        sqft_living15  sqft_lot15
# 17399           1180        7220
# 16005           1530        5170
# 8382            1510        9706
# 7381            1720        6600
# 16824           1480        7280
#
# [5 rows x 21 columns]

# %%
len(train_data.columns)
# Out:
# 21

# %% [markdown]
# Amazon SageMaker's XGBoost container expects data in the libSVM or CSV data format. For this example, we'll stick to CSV. Note that the first column must be the target variable and the CSV should not include headers. Also, notice that although repetitive it's easiest to do this after the train|validation|test split rather than before. This avoids any misalignment issues due to random reordering.

# %%
attributes = ['price','bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']
len(attributes)
# Out:
# 19

# %%
train_data = train_data[attributes]

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# train_data = scaler.fit_transform(train_data)
# train_data = pd.DataFrame(train_data)

# %%
train_data.to_csv('train.csv', index=False, header=False)

# %% [markdown]
# ### Upload training data to S3 Bucket

# %%
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')

s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')

# %% [markdown]
# ### Training
#
# First we'll need to specify training parameters to the estimator. This includes:
#
# - The xgboost algorithm container
# - The IAM role to use
# - Training instance type and count
# - S3 location for output data
# - Algorithm hyperparameters
#
# And then a .fit() function which specifies:
#
# S3 location for output data. In this case we have both a training and validation set which are passed in.

# %%
sess = sagemaker.Session()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
xgb = sagemaker.estimator.Estimator(containers[my_region],
                                    role, 
                                    train_instance_count=1, 
                                    train_instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket_name, prefix),
                                    sagemaker_session=sess)
xgb.set_hyperparameters(eta=0.06,
                        alpha=0.8,
                        lambda_bias=0.8,
                        gamma=1000,
                        min_child_weight=6,
                        subsample=0.2,
                        silent=0,
                        early_stopping_rounds=5,
                        objective='reg:linear',
                        num_round=1000)

# %%
xgb.fit({'train': s3_input_train})
# Out:
# 2020-04-24 21:59:48 Starting - Starting the training job...
# 2020-04-24 21:59:49 Starting - Launching requested ML instances......
# 2020-04-24 22:00:58 Starting - Preparing the instances for training......
# 2020-04-24 22:01:55 Downloading - Downloading input data...
# 2020-04-24 22:02:48 Training - Training image download completed. Training in progress..Arguments: train
# [2020-04-24:22:02:49:INFO] Running standalone xgboost training.
# [2020-04-24:22:02:49:INFO] Path /opt/ml/input/data/validation does not exist!
# [2020-04-24:22:02:49:INFO] File size need to be processed in the node: 1.29mb. Available memory size in the node: 8494.99mb
# [2020-04-24:22:02:49:INFO] Determined delimiter of CSV input is ','
# [22:02:49] S3DistributionType set as FullyReplicated
# [22:02:49] 15129x18 matrix with 272322 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [22:02:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [0]#011train-rmse:615139
# Will train until train-rmse hasn't improved in 5 rounds.
# [22:02:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-rmse:582489
# [22:02:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-rmse:551586
# [22:02:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-rmse:522563
# [22:02:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-rmse:495658
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-rmse:469835
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-rmse:446076
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [7]#011train-rmse:423764
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-rmse:402750
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-rmse:383235
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-rmse:364912
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [11]#011train-rmse:347591
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [12]#011train-rmse:330862
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [13]#011train-rmse:315970
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-rmse:301855
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-rmse:288599
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-rmse:276631
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-rmse:265333
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [18]#011train-rmse:254595
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [19]#011train-rmse:244627
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [20]#011train-rmse:235263
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [21]#011train-rmse:226265
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [22]#011train-rmse:217999
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-rmse:210507
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [24]#011train-rmse:203515
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [25]#011train-rmse:197313
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [26]#011train-rmse:191128
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [27]#011train-rmse:185855
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [28]#011train-rmse:179855
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [29]#011train-rmse:174796
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [30]#011train-rmse:170597
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [31]#011train-rmse:166268
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [32]#011train-rmse:162258
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [33]#011train-rmse:158241
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [34]#011train-rmse:154962
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [35]#011train-rmse:152045
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [36]#011train-rmse:149502
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [37]#011train-rmse:146582
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [38]#011train-rmse:144186
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [39]#011train-rmse:141671
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [40]#011train-rmse:139547
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [41]#011train-rmse:137792
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [42]#011train-rmse:135427
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [43]#011train-rmse:133603
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [44]#011train-rmse:131971
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [45]#011train-rmse:130513
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [46]#011train-rmse:129263
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [47]#011train-rmse:127520
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [48]#011train-rmse:126419
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [49]#011train-rmse:125095
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [50]#011train-rmse:124197
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [51]#011train-rmse:123496
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [52]#011train-rmse:122433
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [53]#011train-rmse:121625
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [54]#011train-rmse:120917
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [55]#011train-rmse:120062
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [56]#011train-rmse:119369
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [57]#011train-rmse:118721
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [58]#011train-rmse:118295
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [59]#011train-rmse:117652
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [60]#011train-rmse:117155
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [61]#011train-rmse:116682
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [62]#011train-rmse:116240
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [63]#011train-rmse:115604
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [64]#011train-rmse:115289
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [65]#011train-rmse:114989
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [66]#011train-rmse:114704
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [67]#011train-rmse:114172
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [68]#011train-rmse:113802
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [69]#011train-rmse:113612
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [70]#011train-rmse:113350
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [71]#011train-rmse:112945
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [72]#011train-rmse:112628
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [73]#011train-rmse:112170
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [74]#011train-rmse:111940
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [75]#011train-rmse:111525
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [76]#011train-rmse:111320
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [77]#011train-rmse:111103
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [78]#011train-rmse:110922
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [79]#011train-rmse:110783
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [80]#011train-rmse:110591
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [81]#011train-rmse:110371
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [82]#011train-rmse:110200
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [83]#011train-rmse:110032
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [84]#011train-rmse:109801
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [85]#011train-rmse:109693
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [86]#011train-rmse:109430
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [87]#011train-rmse:109230
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [88]#011train-rmse:109089
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [89]#011train-rmse:108883
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [90]#011train-rmse:108761
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [91]#011train-rmse:108592
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [92]#011train-rmse:108489
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [93]#011train-rmse:108450
# [94]#011train-rmse:108053
# [95]#011train-rmse:108005
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [96]#011train-rmse:107865
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [97]#011train-rmse:107631
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [98]#011train-rmse:107580
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [99]#011train-rmse:107446
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [100]#011train-rmse:107425
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [101]#011train-rmse:107311
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [102]#011train-rmse:107234
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [103]#011train-rmse:107080
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [104]#011train-rmse:106837
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [105]#011train-rmse:106729
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [106]#011train-rmse:106561
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [107]#011train-rmse:106473
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [108]#011train-rmse:106425
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [109]#011train-rmse:106275
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [110]#011train-rmse:106066
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [111]#011train-rmse:105982
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [112]#011train-rmse:105838
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [113]#011train-rmse:105659
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [114]#011train-rmse:105573
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [115]#011train-rmse:105420
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [116]#011train-rmse:105331
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [117]#011train-rmse:105202
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [118]#011train-rmse:105064
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [119]#011train-rmse:104997
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [120]#011train-rmse:104809
# [22:02:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [121]#011train-rmse:104729
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [122]#011train-rmse:104658
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [123]#011train-rmse:104573
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [124]#011train-rmse:104430
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [125]#011train-rmse:104371
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [126]#011train-rmse:104293
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [127]#011train-rmse:104166
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [128]#011train-rmse:104087
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [129]#011train-rmse:103995
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [130]#011train-rmse:103882
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [131]#011train-rmse:103822
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [132]#011train-rmse:103718
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [133]#011train-rmse:103693
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [134]#011train-rmse:103580
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [135]#011train-rmse:103573
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [136]#011train-rmse:103452
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [137]#011train-rmse:103312
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [138]#011train-rmse:103246
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [139]#011train-rmse:103211
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [140]#011train-rmse:103170
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [141]#011train-rmse:103115
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [142]#011train-rmse:103059
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [143]#011train-rmse:103040
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [144]#011train-rmse:102986
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [145]#011train-rmse:102916
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [146]#011train-rmse:102740
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [147]#011train-rmse:102649
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [148]#011train-rmse:102608
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [149]#011train-rmse:102530
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [150]#011train-rmse:102427
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [151]#011train-rmse:102315
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [152]#011train-rmse:102206
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [153]#011train-rmse:102188
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [154]#011train-rmse:102059
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [155]#011train-rmse:101904
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [156]#011train-rmse:101709
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [157]#011train-rmse:101422
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [158]#011train-rmse:101421
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [159]#011train-rmse:101416
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [160]#011train-rmse:101326
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [161]#011train-rmse:101287
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [162]#011train-rmse:101238
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [163]#011train-rmse:101137
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [164]#011train-rmse:101043
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [165]#011train-rmse:100836
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [166]#011train-rmse:100810
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [167]#011train-rmse:100731
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [168]#011train-rmse:100693
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [169]#011train-rmse:100593
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [170]#011train-rmse:100492
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [171]#011train-rmse:100467
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [172]#011train-rmse:100422
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [173]#011train-rmse:100307
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [174]#011train-rmse:100228
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [175]#011train-rmse:100186
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [176]#011train-rmse:100097
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [177]#011train-rmse:100046
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [178]#011train-rmse:100038
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [179]#011train-rmse:99999
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [180]#011train-rmse:99912.9
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [181]#011train-rmse:99794.2
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [182]#011train-rmse:99748.5
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [183]#011train-rmse:99636.1
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [184]#011train-rmse:99588.8
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [185]#011train-rmse:99490
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [186]#011train-rmse:99438.9
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [187]#011train-rmse:99428
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [188]#011train-rmse:99254.8
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [189]#011train-rmse:99170.4
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [190]#011train-rmse:99074
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [191]#011train-rmse:98990.4
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [192]#011train-rmse:98875.3
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [193]#011train-rmse:98798.9
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [194]#011train-rmse:98755.9
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [195]#011train-rmse:98689.9
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [196]#011train-rmse:98670.2
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [197]#011train-rmse:98652.3
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [198]#011train-rmse:98580
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [199]#011train-rmse:98515.4
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [200]#011train-rmse:98457.4
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [201]#011train-rmse:98387.4
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [202]#011train-rmse:98328.4
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [203]#011train-rmse:98308.2
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [204]#011train-rmse:98275.4
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [205]#011train-rmse:98183.2
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [206]#011train-rmse:98125.7
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [207]#011train-rmse:98112.9
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [208]#011train-rmse:98028.4
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [209]#011train-rmse:98007.4
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [210]#011train-rmse:97972.9
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [211]#011train-rmse:97856.1
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [212]#011train-rmse:97849.4
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [213]#011train-rmse:97810.1
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [214]#011train-rmse:97795.2
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [215]#011train-rmse:97739.7
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [216]#011train-rmse:97680
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [217]#011train-rmse:97595.8
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [218]#011train-rmse:97558.9
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [219]#011train-rmse:97549
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [220]#011train-rmse:97509.7
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [221]#011train-rmse:97418.9
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [222]#011train-rmse:97309.9
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [223]#011train-rmse:97221.9
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [224]#011train-rmse:97170.6
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [225]#011train-rmse:97121.7
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [226]#011train-rmse:97096.8
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [227]#011train-rmse:97061.6
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [228]#011train-rmse:96931.6
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [229]#011train-rmse:96900.4
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [230]#011train-rmse:96900
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [231]#011train-rmse:96847.7
# [22:02:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [232]#011train-rmse:96780.3
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [233]#011train-rmse:96736.1
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [234]#011train-rmse:96656
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [235]#011train-rmse:96626
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [236]#011train-rmse:96565.6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [237]#011train-rmse:96468.2
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [238]#011train-rmse:96368.6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [239]#011train-rmse:96284.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [240]#011train-rmse:96188.6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [241]#011train-rmse:96126.4
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [242]#011train-rmse:96100.4
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [243]#011train-rmse:95860.3
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [244]#011train-rmse:95821.1
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [245]#011train-rmse:95718.6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [246]#011train-rmse:95606.9
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [247]#011train-rmse:95597.7
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [248]#011train-rmse:95544.6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [249]#011train-rmse:95479.7
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [250]#011train-rmse:95424.9
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [251]#011train-rmse:95400.6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [252]#011train-rmse:95370.6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [253]#011train-rmse:95332.1
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [254]#011train-rmse:95259.9
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [255]#011train-rmse:95181.1
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [256]#011train-rmse:95122.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [257]#011train-rmse:95074.2
# [258]#011train-rmse:95031.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [259]#011train-rmse:95014.1
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [260]#011train-rmse:94899.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [261]#011train-rmse:94864.2
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [262]#011train-rmse:94858.1
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [263]#011train-rmse:94876.6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [264]#011train-rmse:94835.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [265]#011train-rmse:94813.3
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [266]#011train-rmse:94827.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [267]#011train-rmse:94747.6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [268]#011train-rmse:94754.8
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [269]#011train-rmse:94699.1
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [270]#011train-rmse:94636.8
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [271]#011train-rmse:94575.3
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [272]#011train-rmse:94546.4
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [273]#011train-rmse:94464.3
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [274]#011train-rmse:94428.1
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [275]#011train-rmse:94373.2
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [276]#011train-rmse:94321
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [277]#011train-rmse:94309.3
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [278]#011train-rmse:94207.4
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [279]#011train-rmse:94168.9
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [280]#011train-rmse:94144.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [281]#011train-rmse:94101
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [282]#011train-rmse:94044.6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [283]#011train-rmse:93994.6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [284]#011train-rmse:93978
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [285]#011train-rmse:93984.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [286]#011train-rmse:93929.7
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [287]#011train-rmse:93828.1
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [288]#011train-rmse:93791
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [289]#011train-rmse:93746.6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [290]#011train-rmse:93747.9
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [291]#011train-rmse:93715.3
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [292]#011train-rmse:93681.3
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [293]#011train-rmse:93624.7
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [294]#011train-rmse:93611.4
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [295]#011train-rmse:93562.1
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [296]#011train-rmse:93513.2
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [297]#011train-rmse:93499.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [298]#011train-rmse:93491.8
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [299]#011train-rmse:93463.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [300]#011train-rmse:93417.3
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [301]#011train-rmse:93387.6
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [302]#011train-rmse:93376.7
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [303]#011train-rmse:93327.7
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [304]#011train-rmse:93281.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [305]#011train-rmse:93142.8
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [306]#011train-rmse:93098.7
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [307]#011train-rmse:93070.1
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [308]#011train-rmse:93050.8
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [309]#011train-rmse:93046.4
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [310]#011train-rmse:93001.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [311]#011train-rmse:92833.1
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [312]#011train-rmse:92544
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [313]#011train-rmse:92454.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [314]#011train-rmse:92420.9
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [315]#011train-rmse:92422.7
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [316]#011train-rmse:92341.2
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [317]#011train-rmse:92349.9
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [318]#011train-rmse:92291.8
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [319]#011train-rmse:92199.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [320]#011train-rmse:92158.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [321]#011train-rmse:92120.2
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [322]#011train-rmse:92050
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [323]#011train-rmse:91974.4
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [324]#011train-rmse:91903.9
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [325]#011train-rmse:91836
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [326]#011train-rmse:91769.8
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [327]#011train-rmse:91736.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [328]#011train-rmse:91695.3
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [329]#011train-rmse:91648.4
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [330]#011train-rmse:91638.2
# [331]#011train-rmse:91606.2
# [332]#011train-rmse:91547.1
# [333]#011train-rmse:91484.1
# [334]#011train-rmse:91435.5
# [22:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [22:02:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [22:02:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [22:02:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [22:02:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [335]#011train-rmse:91395.3
# [22:02:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [336]#011train-rmse:91347.2
# [22:02:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [337]#011train-rmse:91295.8
# ...
# [886]#011train-rmse:70696.6
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [887]#011train-rmse:70693.5
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [888]#011train-rmse:70634.4
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [889]#011train-rmse:70629.7
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [890]#011train-rmse:70613
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [891]#011train-rmse:70573.8
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [892]#011train-rmse:70558.3
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [893]#011train-rmse:70510.7
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [894]#011train-rmse:70480
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [895]#011train-rmse:70452.4
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [896]#011train-rmse:70424.6
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [897]#011train-rmse:70403.4
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [898]#011train-rmse:70380.7
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [899]#011train-rmse:70348.6
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [900]#011train-rmse:70344.3
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [901]#011train-rmse:70328.4
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [902]#011train-rmse:70311.8
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [903]#011train-rmse:70287.6
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [904]#011train-rmse:70262.6
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [905]#011train-rmse:70224.1
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [906]#011train-rmse:70165.7
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [907]#011train-rmse:70128
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [908]#011train-rmse:70122.6
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [909]#011train-rmse:70101
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [910]#011train-rmse:70094.2
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [911]#011train-rmse:70068.2
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [912]#011train-rmse:70043.1
# [22:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [913]#011train-rmse:70038.5
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [914]#011train-rmse:69989
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [915]#011train-rmse:69981.5
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [916]#011train-rmse:69965.4
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [917]#011train-rmse:69911
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [918]#011train-rmse:69905.4
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [919]#011train-rmse:69883.6
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [920]#011train-rmse:69873.2
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [921]#011train-rmse:69826.5
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [922]#011train-rmse:69818.5
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [923]#011train-rmse:69811.3
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [924]#011train-rmse:69804.9
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [925]#011train-rmse:69762.5
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [926]#011train-rmse:69758.8
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [927]#011train-rmse:69733.4
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [928]#011train-rmse:69702.9
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [929]#011train-rmse:69685.5
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [930]#011train-rmse:69650.9
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [931]#011train-rmse:69648.2
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [932]#011train-rmse:69624.6
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [933]#011train-rmse:69604.4
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [934]#011train-rmse:69597.7
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [935]#011train-rmse:69570.2
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [936]#011train-rmse:69535
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [937]#011train-rmse:69493.5
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [938]#011train-rmse:69473.1
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [939]#011train-rmse:69457.3
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [940]#011train-rmse:69419.4
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [941]#011train-rmse:69404.2
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [942]#011train-rmse:69387.1
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [943]#011train-rmse:69359.4
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [944]#011train-rmse:69336.7
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [945]#011train-rmse:69315
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [946]#011train-rmse:69304.1
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [947]#011train-rmse:69289.2
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [948]#011train-rmse:69271.6
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [949]#011train-rmse:69217.7
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [950]#011train-rmse:69195.7
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [951]#011train-rmse:69168.6
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [952]#011train-rmse:69148.6
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [953]#011train-rmse:69115.8
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [954]#011train-rmse:69082
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [955]#011train-rmse:69067.3
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [956]#011train-rmse:69031.7
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [957]#011train-rmse:69010
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [958]#011train-rmse:68990.1
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [959]#011train-rmse:68952.2
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [960]#011train-rmse:68935.2
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [961]#011train-rmse:68914.6
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [962]#011train-rmse:68893.7
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [963]#011train-rmse:68874.2
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [964]#011train-rmse:68860.8
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [965]#011train-rmse:68835.3
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [966]#011train-rmse:68791.9
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [967]#011train-rmse:68767.7
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [968]#011train-rmse:68751.2
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [969]#011train-rmse:68675.5
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [970]#011train-rmse:68644.5
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [971]#011train-rmse:68618.3
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [972]#011train-rmse:68606.9
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [973]#011train-rmse:68570.4
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [974]#011train-rmse:68546
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [975]#011train-rmse:68534.5
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [976]#011train-rmse:68514.2
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [977]#011train-rmse:68472.6
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [978]#011train-rmse:68447.3
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [979]#011train-rmse:68451.9
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [980]#011train-rmse:68434.8
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [981]#011train-rmse:68399.7
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [982]#011train-rmse:68362.8
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [983]#011train-rmse:68328.6
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [984]#011train-rmse:68307.1
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [985]#011train-rmse:68280.5
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [986]#011train-rmse:68279.5
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [987]#011train-rmse:68224.6
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [988]#011train-rmse:68187.8
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [989]#011train-rmse:68139.8
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [990]#011train-rmse:68109.7
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [991]#011train-rmse:68091.1
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [992]#011train-rmse:68087.9
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [993]#011train-rmse:68080.8
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [994]#011train-rmse:68053.9
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [995]#011train-rmse:68012.8
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [996]#011train-rmse:68008.5
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [997]#011train-rmse:67981.1
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [998]#011train-rmse:67967.6
# [22:02:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [999]#011train-rmse:67959.6
#
# 2020-04-24 22:03:06 Uploading - Uploading generated training model
# 2020-04-24 22:03:06 Completed - Training job completed
# Training seconds: 71
# Billable seconds: 71

# %%
xgb_predictor = xgb.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge')
# Out:
# ----------------!

# %%
test_data
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 9581   5466310730 2014-08-22   165000.0         3       2.50         1660
# 11264  7950303290 2015-04-02   499950.0         3       1.75         2060
# 15165  3034200660 2014-06-19   507000.0         3       2.50         2120
# 10336  7525300240 2015-02-19   750000.0         4       2.25         2820
# 9861   7805450560 2014-08-20   960000.0         4       2.50         3110
# 6771   5442300807 2014-06-24  2700000.0         5       2.75         3831
# 16671  9250900104 2014-11-10   300000.0         5       1.75         2110
# 10849  1446401555 2014-12-08   292000.0         3       1.75         1320
# 17419  6138000095 2014-11-18   219000.0         3       1.00         1080
# 18304  1425039029 2014-09-23  1230000.0         5       4.00         4390
# 3352   5021900090 2015-03-06  1100000.0         5       2.75         2830
# 7119   1148000005 2014-06-23   346000.0         3       1.75         1270
# 17852  6791200120 2015-04-07   515000.0         3       2.25         1820
# 21499  6891100090 2014-10-14   850000.0         5       3.50         4200
# 8470   2141340040 2014-09-11   649950.0         3       2.50         2150
# 1184   7856610200 2014-05-23   902000.0         4       2.25         2530
# 14808  7855000325 2015-02-20  1050000.0         4       3.00         3080
# 4757    868001705 2015-02-06  1465000.0         3       1.50         2480
# 19189  7375300100 2014-11-24   400000.0         3       1.50         1510
# 20181  7853400250 2015-02-19   645000.0         4       3.50         2910
# 20919  9578140180 2014-06-11   329950.0         3       2.50         2456
# 20083  2143700756 2014-09-29   388000.0         4       2.50         2090
# 14122  3856904825 2014-11-04   380000.0         2       1.00          980
# 11351  6031400071 2015-01-14   270000.0         4       2.50         1670
# 17744  9358400150 2015-02-06   635000.0         5       3.50         4150
# 21492  7283900306 2015-04-17   400000.0         3       2.50         1910
# 16288  1549500585 2015-04-27   585000.0         3       2.00         2220
# 265    8078560140 2014-05-19   290000.0         4       2.50         1700
# 20959  2222059154 2014-08-13   407000.0         4       2.50         2927
# 11361  3303860030 2014-10-29   495000.0         4       2.50         4060
# ...           ...        ...        ...       ...        ...          ...
# 1527   7923500060 2014-09-22   713000.0         5       2.75         2580
# 15067  6139100101 2015-05-05   405100.0         4       2.00         1580
# 1239   5166700055 2015-05-04   645000.0         4       2.75         2340
# 15680  1330850130 2015-02-18   799990.0         3       2.50         2850
# 18884  1626069220 2014-09-05   562000.0         3       2.50         2400
# 6258   5406500480 2014-07-21   668000.0         4       2.50         2670
# 3365   6052400625 2015-03-26   406000.0         4       1.50         1920
# 4867   5561300480 2015-04-08   600000.0         7       2.25         3170
# 21313  8562770050 2014-05-27   627000.0         3       3.50         2710
# 11934  3179101580 2014-05-28  1210000.0         4       2.75         3650
# 11189  1774220400 2014-05-13   591000.0         4       2.25         2710
# 12544   871000515 2014-12-05   567500.0         2       1.50         1350
# 4477   4054500590 2014-06-26   910000.0         4       3.50         4040
# 18828  1455100355 2014-07-08  1675000.0         3       2.50         3490
# 17275  5259800440 2014-09-26   232000.0         3       1.75         1290
# 20848  7967000270 2014-11-25   353000.0         4       2.50         1912
# 6092   2268000050 2014-07-21   229900.0         3       1.00         1010
# 16179  4059400585 2014-06-24   218000.0         3       1.00          880
# 403    1151100070 2015-02-24   437000.0         3       2.50         1750
# 7083   2817260130 2014-06-13   622500.0         5       2.75         3320
# 6889   7788400170 2014-09-26   230000.0         3       1.00          940
# 1217   6321000045 2014-12-22  1875000.0         5       3.25         4110
# 10787  6411600370 2014-05-15   475000.0         7       3.50         2870
# 8507   3649100304 2014-08-19   400000.0         3       2.25         1740
# 6029   3629870020 2014-11-14   575000.0         3       2.50         1870
# 13379  2131200925 2014-07-29   331292.0         3       1.75         1660
# 11646  1796200140 2015-03-09   270000.0         3       1.75         2840
# 1267   4310701600 2014-11-13   340000.0         3       2.50         1240
# 3174   5561301280 2014-05-05   410000.0         3       2.25         1800
# 1677   2320069248 2014-07-01   165050.0         3       1.00         1200
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 9581       2415     2.0           0     0  ...      7        1660
# 11264      3500     1.0           0     0  ...      7        1030
# 15165      7201     2.0           0     0  ...      8        2120
# 10336      9602     1.0           0     1  ...      8        1950
# 9861      11397     2.0           0     3  ...     10        3110
# 6771      13800     2.0           1     4  ...      9        3831
# 16671      8500     1.0           0     0  ...      7        1100
# 10849      6600     1.0           0     0  ...      7        1320
# 17419     10639     1.5           0     0  ...      7        1080
# 18304      6656     2.0           0     0  ...      9        2930
# 3352      18050     1.0           0     0  ...      7        1630
# 7119       8100     1.0           0     0  ...      6         880
# 17852     13362     1.0           0     0  ...      8        1220
# 21499      5400     2.0           0     0  ...      9        3140
# 8470      15304     2.0           0     0  ...      9        2150
# 1184       9200     1.0           0     0  ...      9        1570
# 14808     10757     2.0           0     3  ...      8        3080
# 4757       9900     2.0           0     3  ...     10        2130
# 19189      7642     1.0           0     0  ...      7        1510
# 20181      5260     2.0           0     0  ...      9        2910
# 20919      7566     2.0           0     0  ...      8        2456
# 20083      5040     2.0           0     0  ...      9        2090
# 14122      3400     1.0           0     0  ...      7         980
# 11351      8056     1.0           0     0  ...      7        1170
# 17744     13232     2.0           0     0  ...     11        4150
# 21492      4408     3.0           0     0  ...      8        1910
# 16288    209523     1.0           0     0  ...      7        2220
# 265        7280     2.0           0     0  ...      7        1700
# 20959      6000     2.0           0     0  ...      7        2927
# 11361      8547     2.0           0     0  ...      9        2790
# ...         ...     ...         ...   ...  ...    ...         ...
# 1527       9242     2.0           0     2  ...      8        1720
# 15067      7300     1.0           0     0  ...      7        1580
# 1239       6350     1.0           0     0  ...      7        1310
# 15680     21780     2.0           0     0  ...     10        2850
# 18884     97138     2.0           0     0  ...      8        2400
# 6258       4410     2.0           0     0  ...      8        2670
# 3365       6000     2.0           0     1  ...      7        1920
# 4867      36384     2.0           0     0  ...      8        3170
# 21313      3475     2.0           0     0  ...      8        1650
# 11934      6982     2.0           0     2  ...      9        2530
# 11189     38180     2.0           0     0  ...      8        2710
# 12544      4592     1.0           0     0  ...      7        1070
# 4477      50479     2.0           0     0  ...     11        4040
# 18828      8343     2.0           1     4  ...      9        2150
# 17275      6604     1.0           0     0  ...      7        1290
# 20848      5000     2.0           0     0  ...      8        1912
# 6092       8848     1.0           0     0  ...      7        1010
# 16179     18205     1.0           0     0  ...      6         880
# 403       22357     2.0           0     0  ...      8        1750
# 7083      23760     2.0           0     0  ...      8        2190
# 6889      10875     1.0           0     0  ...      7         940
# 1217       7920     2.0           0     3  ...      9        3150
# 10787     29699     1.0           0     0  ...      7        1520
# 8507      11040     2.0           0     0  ...      8        1740
# 6029       3485     2.0           0     0  ...      8        1870
# 13379     10000     1.0           0     0  ...      7        1660
# 11646      9800     1.0           0     0  ...      7        1420
# 1267       1115     3.0           0     0  ...      8        1240
# 3174      36704     1.0           0     0  ...      8        1360
# 1677       8514     1.0           0     0  ...      7        1200
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 9581               0      1983             0    98042  47.3763 -122.148
# 11264           1030      1951             0    98118  47.5635 -122.282
# 15165              0      2003             0    98133  47.7174 -122.337
# 10336            870      1974             0    98008  47.5881 -122.113
# 9861               0      1984             0    98006  47.5623 -122.106
# 6771               0      1959          1980    98040  47.5919 -122.251
# 16671           1010      1962             0    98133  47.7737 -122.350
# 10849              0      1988             0    98168  47.4838 -122.330
# 17419              0      1953             0    98002  47.3171 -122.219
# 18304           1460      2008             0    98199  47.6480 -122.397
# 3352            1200      1958             0    98040  47.5773 -122.226
# 7119             390      1950             0    98146  47.4828 -122.344
# 17852            600      1977             0    98075  47.5898 -122.052
# 21499           1060      2012             0    98052  47.7077 -122.120
# 8470               0      1979             0    98006  47.5573 -122.136
# 1184             960      1976             0    98006  47.5612 -122.152
# 14808              0      1961             0    98006  47.5671 -122.159
# 4757             350      1940             0    98177  47.7018 -122.381
# 19189              0      1959             0    98008  47.5978 -122.116
# 20181              0      2012             0    98065  47.5168 -121.883
# 20919              0      2012             0    98023  47.2970 -122.351
# 20083              0      2014             0    98055  47.4797 -122.230
# 14122              0      1923             0    98105  47.6688 -122.323
# 11351            500      1961             0    98168  47.4884 -122.319
# 17744              0      2006             0    98003  47.3417 -122.182
# 21492              0      2007             0    98133  47.7634 -122.350
# 16288              0      1991             0    98019  47.7586 -121.911
# 265                0      1988             0    98031  47.4045 -122.171
# 20959              0      2011             0    98042  47.3737 -122.160
# 11361           1270      2007             0    98038  47.3694 -122.056
# ...              ...       ...           ...      ...      ...      ...
# 1527             860      1967             0    98007  47.5943 -122.133
# 15067              0      1955             0    98155  47.7598 -122.328
# 1239            1030      1974             0    98126  47.5559 -122.379
# 15680              0      1994             0    98053  47.6455 -122.040
# 18884              0      1983             0    98077  47.7361 -122.046
# 6258               0      1999             0    98075  47.5978 -122.038
# 3365               0      1951             0    98198  47.4029 -122.321
# 4867               0      1969             0    98027  47.4654 -122.003
# 21313           1060      2005             0    98027  47.5359 -122.072
# 11934           1120      1951          2003    98115  47.6756 -122.275
# 11189              0      1977             0    98077  47.7700 -122.097
# 12544            280      1939             0    98199  47.6511 -122.405
# 4477               0      1987             0    98077  47.7196 -122.048
# 18828           1340      1939          1991    98125  47.7265 -122.281
# 17275              0      1984             0    98023  47.3230 -122.349
# 20848              0      2012             0    98001  47.3511 -122.275
# 6092               0      1968             0    98003  47.2742 -122.299
# 16179              0      1945             0    98178  47.5013 -122.244
# 403                0      1994             0    98045  47.4807 -121.779
# 7083            1130      1975             0    98072  47.7498 -122.146
# 6889               0      1957             0    98056  47.5121 -122.168
# 1217             960      1921             0    98122  47.6170 -122.282
# 10787           1350      1961             0    98125  47.7153 -122.327
# 8507               0      1980             0    98028  47.7376 -122.242
# 6029               0      2001             0    98029  47.5493 -122.004
# 13379              0      1972             0    98019  47.7410 -121.978
# 11646           1420      1977             0    98042  47.3516 -122.119
# 1267               0      2003             0    98103  47.6985 -122.340
# 3174             440      1978             0    98027  47.4688 -122.013
# 1677               0      1959             0    98022  47.2043 -122.008
#
#        sqft_living15  sqft_lot15
# 9581            1740        2624
# 11264           1110        6000
# 15165           1930        7206
# 10336           2890        9602
# 9861            3110       11586
# 6771            3850       36563
# 16671           2020        8500
# 10849           1070        6594
# 17419           1470       10600
# 18304           1560        6656
# 3352            2370       14250
# 7119            1650        8173
# 17852           2050       15000
# 21499           3300        5564
# 8470            2540       10507
# 1184            3030        9400
# 14808           2810       10757
# 4757            2860        9288
# 19189           2180        8357
# 20181           2910        5260
# 20919           2478        7212
# 20083           1430       12000
# 14122           1200        3420
# 11351           1360        8056
# 17744           3840       15121
# 21492           1910        8154
# 16288           1600      210830
# 265             1950        7475
# 20959           2533        6000
# 11361           2810        8313
# ...              ...         ...
# 1527            2240        9316
# 15067           1180        9450
# 1239            2020        6350
# 15680           3020       21798
# 18884           2230       54450
# 6258            2670        4410
# 3365            1920        6000
# 4867            2460       38370
# 21313           2440        2867
# 11934           3140        7894
# 11189           2590       38180
# 12544           1610        5102
# 4477            3770       40899
# 18828           2990       13104
# 17275           1440        6682
# 20848           2020        5000
# 6092            1380       10650
# 16179           1110       16115
# 403             2430       22357
# 7083            2520       36720
# 6889            1250       11200
# 1217            3890        7800
# 10787           1380        7555
# 8507            1720       11778
# 6029            1940        3485
# 13379           1770       10000
# 11646           1650        9590
# 1267            1410        1355
# 3174            2730       36404
# 1677            1210        8985
#
# [6484 rows x 21 columns]

# %% [markdown]
# ### Evaluation
#
# There are many ways to compare the performance of a machine learning model, but let's start by simply comparing actual to predicted values.
#
# First we'll need to determine how we pass data into and receive data from our endpoint. Our data is currently stored as NumPy arrays in memory of our notebook instance. To send it in an HTTP POST request, we'll serialize it as a CSV string and then decode the resulting CSV.
#
# Note: For inference with CSV format, SageMaker XGBoost requires that the data does NOT include the target variable.

# %%
test_data_array = test_data.drop(['date', 'price','id'], axis=1).values #load the data into an array

# %%
test_data_array
# Out:
# array([[ 3.00000e+00,  2.50000e+00,  1.66000e+03, ..., -1.22148e+02,
#          1.74000e+03,  2.62400e+03],
#        [ 3.00000e+00,  1.75000e+00,  2.06000e+03, ..., -1.22282e+02,
#          1.11000e+03,  6.00000e+03],
#        [ 3.00000e+00,  2.50000e+00,  2.12000e+03, ..., -1.22337e+02,
#          1.93000e+03,  7.20600e+03],
#        ...,
#        [ 3.00000e+00,  2.50000e+00,  1.24000e+03, ..., -1.22340e+02,
#          1.41000e+03,  1.35500e+03],
#        [ 3.00000e+00,  2.25000e+00,  1.80000e+03, ..., -1.22013e+02,
#          2.73000e+03,  3.64040e+04],
#        [ 3.00000e+00,  1.00000e+00,  1.20000e+03, ..., -1.22008e+02,
#          1.21000e+03,  8.98500e+03]])

# %%
xgb_predictor.content_type = 'text/csv' # set the data type for an inference
xgb_predictor.serializer = csv_serializer # set the serializer type

# %%
predictions = xgb_predictor.predict(test_data_array).decode('utf-8') # predict!
predictions_array = np.fromstring(predictions[1:], sep=',') # and turn the prediction into an array
print(predictions_array.shape)
# Out:
# (6484,)

# %%
from sklearn.metrics import r2_score
print("R2 score : %.2f" % r2_score(test_data['price'],predictions_array))
# Out:
# R2 score : 0.87

# %%
import seaborn as sns
sns.set(style="darkgrid")

plt.scatter(test_data['price'],predictions_array)
#plt.plot(test_data['price'],predictions_array, color='blue', linewidth=1)

plt.xticks(())
plt.yticks(())

plt.show()

# %% [markdown]
# ## Integrating Amazon SageMaker Endpoints into Internet-facing Applications
#
# In a production environment, you might have an internet-facing application sending requests to the endpoint for inference. The following high-level example shows how to integrate your model endpoint into your application.
#
# For an example of how to use Amazon API Gateway and AWS Lambda to set up and deploy a web service that you can call from a client application -
#
# - Create an IAM role that the AWS Lambda service principal can assume. Give the role permissions to call the Amazon SageMaker InvokeEndpoint API.
#
# - Create a Lambda function that calls the Amazon SageMaker InvokeEndpoint API.
#
# - Call the Lambda function from a mobile application.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://aws.amazon.com/blogs/machine-learning/call-an-amazon-sagemaker-model-endpoint-using-amazon-api-gateway-and-aws-lambda/

# %% [markdown]
# ### Optional Clean-up
#
# If you are done with this notebook, please run the cell below. This will remove the hosted endpoint you created and avoid any charges from a stray instance being left on.

# %%
sagemaker.Session().delete_endpoint(xgb_predictor.endpoint)
bucket_to_delete = boto3.resource('s3').Bucket(bucket_name)
bucket_to_delete.objects.all().delete()
# Out:
# [{'ResponseMetadata': {'RequestId': '98875884920A7407',
#    'HostId': 'dr3/tddOnThxXf3TJOYbEYvJehTlU6HEEQbduokto6edbi2n6QO2fVs8AXESf8SSkuuCbAajG08=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'dr3/tddOnThxXf3TJOYbEYvJehTlU6HEEQbduokto6edbi2n6QO2fVs8AXESf8SSkuuCbAajG08=',
#     'x-amz-request-id': '98875884920A7407',
#     'date': 'Fri, 24 Apr 2020 22:14:14 GMT',
#     'connection': 'close',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'sagemaker/sklearncontainer/housing_test.csv'},
#    {'Key': 'sagemaker/wimlds-sagemaker-xgboost-demo/train/train.csv'},
#    {'Key': 'sagemaker/sklearncontainer/housing_train.csv'},
#    {'Key': 'sagemaker/wimlds-sagemaker-xgboost-demo/output/xgboost-2020-04-24-21-59-48-478/output/model.tar.gz'},
#    {'Key': 'rf-scikit-2020-04-24-21-48-57-211/debug-output/training_job_end.ts'},
#    {'Key': 'rf-scikit-2020-04-24-21-48-57-211/output/model.tar.gz'},
#    {'Key': 'rf-scikit-2020-04-24-21-48-57-211/source/sourcedir.tar.gz'}]}]

# %% [markdown]
# [Amazon Sagemaker Pricing](https://aws.amazon.com/sagemaker/pricing/)
#
# Try Amazon SageMaker for two months, free!
#
# As part of the AWS Free Tier, you can get started with Amazon SageMaker for free. If you have never used Amazon SageMaker before, for the first two months, you are offered a monthly free tier of 250 hours of t2.medium or t3.medium notebook usage for building your models, plus 50 hours of m4.xlarge or m5.xlarge for training, plus 125 hours of m4.xlarge or m5.xlarge for deploying your machine learning models for real-time inferencing and batch transform with Amazon SageMaker. Your free tier starts from the first month when you create your first SageMaker resource.

# %% [markdown]
# ### References
#
# 1. Diego Lopez Yse(Apr 17, 2019). Decision tree. Retrieved from Medium: https://towardsdatascience.com/the-complete-guide-to-decision-trees-28a4e3c7be14
#
# 2. Jinde Shubham.(Jul 3, 2018).  Ensemble learning is Fable of blind men and  elephant. Retrieved from Medium :https://becominghuman.ai/ensemble-learning-bagging-and-boosting-d20f38be9b1e
#
# 2. Subramaniam, Prashanth & Kaur, Maninder. (2019). Review of Security in Mobile Edge Computing with Deep Learning. 1-5. 10.1109/ICASET.2019.8714349.
#
# 3. Zulaikha Lateef(Jun 28,2019). Bagging and Boosting . Retrieved from Edureka.co :https://www.edureka.co/blog/boosting-machine-learning/
#
# 4. Tianqi Chen and Carlos Guestrin. 2016. XGBoost: A Scalable Tree Boosting System. In Proceedings of the 22nd ACM SIGKDD International Conference on Knowledge Discovery and Data Mining (KDD ’16). Association for Computing Machinery, New York, NY, USA, 785–794. DOI:https://doi.org/10.1145/2939672.2939785
#
# 5.  AWS SageMaker Screenshots and figures. Retrieved from Amazon Web Services, Inc. : https://docs.aws.amazon.com/sagemaker/#amazon-sagemaker-overview
